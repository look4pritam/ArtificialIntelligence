# %% [markdown]
# # Use TensorFlow 1.x.

# %%
try:
  # %tensorflow_version 1.x
except Exception:
  pass

import tensorflow as tf
print(tf.__version__)

# %% [markdown]
# # Install gdown Python package.

# %%
# !pip install -U --no-cache-dir gdown

# %% [markdown]
# # Download CelebA dataset.

# %% [markdown]
# ### Download CelebA dataset.
# *   Download the dataset from Google drive.

# %%
# !gdown --id 1diaLDdB-dNMsPhJX0uco4155ghi4KMXK

# %% [markdown]
# ### OR

# %%
#!gdown --id 1z5bpHVrciXmE8obe8NeYa3u9zWvdLWwS

# %% [markdown]
# ### See downloaded CelebA dataset.

# %%
# !ls -al

# %% [markdown]
# ### Extract CelebA dataset at appropiate location.

# %%
# !tar -xzf img_align_celeba.tar.gz

# %%
# !rm -rf img_align_celeba.tar.gz

# %% [markdown]
# ### See extracted CelebA dataset.

# %%
# !ls -al
# !ls -al img_align_celeba
# !ls -l img_align_celeba/images | wc -l

# %% [markdown]
# # Install AttGAN dependencies.

# %%
# !pip install opencv-python scikit-image tqdm oyaml

# %% [markdown]
# # Mount the gdrive.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#!mv img_align_celeba.tar.gz '/content/drive/My Drive/CelebA/.'

# %% [markdown]
# ### Set the root directory.

# %%
import os

root_dir = '/content/drive/My Drive/'
os.chdir(root_dir)

# !ls -al

# %% [markdown]
# # Clone AttGAN git repository.

# %% [markdown]
# ### Clone AttGAN git repository.

# %%
# !rm -rf AttGAN-Tensorflow
# !git clone https://github.com/look4pritam/AttGAN-Tensorflow.git

# %% [markdown]
# ### See cloned repository.

# %%
# !pwd

# %%
# !ls -al

# %% [markdown]
# ### Set the root directory.

# %%
import os

root_dir = '/content/drive/My Drive/AttGAN-Tensorflow'
os.chdir(root_dir)

# !ls -al

# %% [markdown]
# # Train AttGAN model.

# %%
# !python train.py \
  --img_dir /content/img_align_celeba/images/ \
  --train_label_path /content/img_align_celeba/train_label.txt \
  --val_label_path /content/img_align_celeba/val_label.txt \
  --load_size 143 \
  --crop_size 128 \
  --model model_128 \
  --experiment_name AttGAN_128

# %% [markdown]
# ### Visualize loss.

# %%
# %reload_ext tensorboard
# %tensorboard --logdir output/AttGAN_128/summaries

# %% [markdown]
# # OR

# %% [markdown]
# # Download AttGAN model weights.

# %% [markdown]
# ### Download AttGAN model-128 weights.
# * Model size 128
# * Contain all weights

# %%
#!gdown --id 1Oy4F1xtYdxj4iyiLyaEd-dkGIJ0mwo41

# %% [markdown]
# ### Download AttGAN generator model-128 weights.

# %%
# !gdown --id 1lcQ-ijNrGD4919eJ5Dv-7ja5rsx5p0Tp

# %% [markdown]
# ### Download AttGAN generator model-384 weights.

# %%
# !gdown --id 1scaKWcWIpTfsV0yrWCI-wg_JDmDsKKm1

# %% [markdown]
# ### See downloaded weights.

# %%
# !ls -al

# %% [markdown]
# ### Extract model weights at appropiate location.

# %%
# !mkdir output

# %%
# !mv AttGAN_128_generator_only.zip output/.
# !unzip output/AttGAN_128_generator_only.zip -d output/

# %%
# !mv AttGAN_384_generator_only.zip output/.
# !unzip output/AttGAN_384_generator_only.zip -d output/

# %% [markdown]
# ### See extracted model weights.

# %%
# !ls -al output
# !ls -al output/AttGAN_128
# !ls -al output/AttGAN_384

# %% [markdown]
# # Test application.

# %% [markdown]
# ### List of all 40 attributes.

# %%
5_o_Clock_Shadow 
Arched_Eyebrows 
Attractive 
Bags_Under_Eyes 
Bald 
Bangs 
Big_Lips 
Big_Nose 
Black_Hair 
Blond_Hair 
Blurry           
Brown_Hair 
Bushy_Eyebrows 
Chubby 
Double_Chin 
Eyeglasses 
Goatee             
Gray_Hair 
Heavy_Makeup 
High_Cheekbones 
Male 
Mouth_Slightly_Open             
Mustache 
Narrow_Eyes 
No_Beard 
Oval_Face 
Pale_Skin 
Pointy_Nose          
Receding_Hairline 
Rosy_Cheeks 
Sideburns 
Smiling 
Straight_Hair 
Wavy_Hair 
Wearing_Earrings 
Wearing_Hat 
Wearing_Lipstick 
Wearing_Necklace 
Wearing_Necktie 
Young

# %% [markdown]
# ### Test application for Male.

# %%
# !python test_slide.py \
  --experiment_name AttGAN_128 \
  --img_dir /content/img_align_celeba/images/ \
  --test_label_path /content/img_align_celeba/test_label.txt \
  --test_att_name Male

# %% [markdown]
# ### Test application for Eyeglasses.

# %%
# !python test_slide.py \
  --experiment_name AttGAN_128 \
  --img_dir /content/img_align_celeba/images/ \
  --test_label_path /content/img_align_celeba/test_label.txt \
  --test_att_name Eyeglasses

# %% [markdown]
# ### Test application for custom dataset for Eyeglasses.

# %%
# !python test_slide.py \
  --experiment_name AttGAN_128 \
  --test_att_name Eyeglasses \
  --img_dir data/img_celeba/custom \
  --test_label_path data/img_celeba/custom_label.txt

# %% [markdown]
# ### Test application for custom dataset for Male.

# %%
# !python test_slide.py \
  --experiment_name AttGAN_128 \
  --test_att_name Male \
  --img_dir data/img_celeba/custom \
  --test_label_path data/img_celeba/custom_label.txt

# %% [markdown]
# ### Test application for custom dataset for Eyeglasses.

# %%
# !python test_slide.py \
  --experiment_name AttGAN_384 \
  --test_att_name Eyeglasses \
  --img_dir data/img_celeba/custom \
  --test_label_path data/img_celeba/custom_label.txt
