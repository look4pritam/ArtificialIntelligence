# %% [markdown]
# <a href="https://colab.research.google.com/github/look4pritam/ArtificialIntelligence/blob/master/MachineLearning/Notebooks/DecisionTree/DecisionTreeClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Decision Tree Classifier
#
# In this example, we will learn to classify a dataset using a [Decision Tree Classifier](https://en.wikipedia.org/wiki/Decision_tree_learning).
#
# We will use an iris dataset for classification.
#
# See [link](https://archive.ics.uci.edu/ml/datasets/iris) for more details.

# %% [markdown]
# # Set the root directory for processing.

# %%
import os

root_dir = '/content/'
os.chdir(root_dir)

# !ls -al
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Dec 20 20:19 .
# drwxr-xr-x 1 root root 4096 Dec 22 04:52 ..
# drwxr-xr-x 4 root root 4096 Dec 20 20:18 .config
# drwxr-xr-x 1 root root 4096 Dec 20 20:19 sample_data

# %% [markdown]
# # Import required python modules.

# %%
import numpy as np
np.random.seed(7)

# %%
import pandas as pd

# %%
from sklearn import datasets

# %% [markdown]
# # Load an iris dataset.

# %% [markdown]
# ### Define feature names.

# %%
feature_names = ['Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width']

# %% [markdown]
# ### Load an iris dataset from sklearn datasets.

# %%
iris_dataset = datasets.load_iris()

# %% [markdown]
# ### Define input variables (X) and an output variable (y).

# %%
X = pd.DataFrame(iris_dataset.data, columns = feature_names)
y = iris_dataset.target

# %% [markdown]
# # Import required python modules.

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # Create a decision tree based classfier.

# %%
model = DecisionTreeClassifier()
model.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Interpret the generated decision tree.

# %% [markdown]
# ### Import required python modules.

# %%
from sklearn.tree import export_graphviz
from six import StringIO

# %%
dot_data = StringIO()
export_graphviz(model, 
                out_file=dot_data,  
                filled=True, 
                rounded=True,
                special_characters=True,
                feature_names=feature_names
                )

# %% [markdown]
# ### Export the generated decision tree as a dot data.

# %%
import pydotplus

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('iris_tree.png')
# Out:
# True

# %% [markdown]
# ### Visualize the generated decision tree.

# %%
from IPython.display import Image  

Image(graph.create_png())
