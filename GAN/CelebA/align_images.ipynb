# %% [markdown]
# # Install gdown Python package.

# %%
# !pip install -U --no-cache-dir gdown

# %% [markdown]
# # Install Python packages.

# %%
# !pip install opencv-python scikit-image tqdm oyaml

# %% [markdown]
# # Clone AttGAN git repository.

# %% [markdown]
# ### Clone AttGAN git repository.

# %%
# !rm -rf AttGAN-Tensorflow
# !git clone https://github.com/look4pritam/AttGAN-Tensorflow.git

# %% [markdown]
# ### See cloned repository.

# %%
# !ls -al

# %% [markdown]
# ### Set the current root directory.

# %%
import os

root_dir = '/content/AttGAN-Tensorflow'
os.chdir(root_dir)

# !ls -al

# %% [markdown]
# # Download CelebA dataset.

# %% [markdown]
# ### Mount Google drive.
# * Location - /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Copy compressed dataset files.
# * Location - img_celeba.7z

# %%
# !ls -al data/img_celeba

# %%
# !mkdir img_celeba.7z

# %%
# !ls -al '/content/drive/My Drive/datasets/CelebA/img_celeba.7z/'

# %%
# !cp '/content/drive/My Drive/datasets/CelebA/img_celeba.7z/img_celeba.7z.001' img_celeba.7z/.
# !cp '/content/drive/My Drive/datasets/CelebA/img_celeba.7z/img_celeba.7z.002' img_celeba.7z/.
# !cp '/content/drive/My Drive/datasets/CelebA/img_celeba.7z/img_celeba.7z.003' img_celeba.7z/.
# !cp '/content/drive/My Drive/datasets/CelebA/img_celeba.7z/img_celeba.7z.004' img_celeba.7z/.
# !cp '/content/drive/My Drive/datasets/CelebA/img_celeba.7z/img_celeba.7z.005' img_celeba.7z/.
# !cp '/content/drive/My Drive/datasets/CelebA/img_celeba.7z/img_celeba.7z.006' img_celeba.7z/.
# !cp '/content/drive/My Drive/datasets/CelebA/img_celeba.7z/img_celeba.7z.007' img_celeba.7z/.
# !cp '/content/drive/My Drive/datasets/CelebA/img_celeba.7z/img_celeba.7z.008' img_celeba.7z/.
# !cp '/content/drive/My Drive/datasets/CelebA/img_celeba.7z/img_celeba.7z.009' img_celeba.7z/.
# !cp '/content/drive/My Drive/datasets/CelebA/img_celeba.7z/img_celeba.7z.010' img_celeba.7z/.
# !cp '/content/drive/My Drive/datasets/CelebA/img_celeba.7z/img_celeba.7z.011' img_celeba.7z/.
# !cp '/content/drive/My Drive/datasets/CelebA/img_celeba.7z/img_celeba.7z.012' img_celeba.7z/.
# !cp '/content/drive/My Drive/datasets/CelebA/img_celeba.7z/img_celeba.7z.013' img_celeba.7z/.
# !cp '/content/drive/My Drive/datasets/CelebA/img_celeba.7z/img_celeba.7z.014' img_celeba.7z/.

# %% [markdown]
# ### See downloaded CelebA dataset.

# %%
# !ls -al
# !ls -al img_celeba.7z

# %% [markdown]
# ### Extract CelebA dataset at appropiate location.

# %%
!7z x '/content/AttGAN-Tensorflow/img_celeba.7z/img_celeba.7z.001' -o./data/img_celeba/ 1>/dev/null 2>/dev/null

# %%
# !ls -l data/img_celeba/img_celeba/ | wc -l

# %% [markdown]
# ### See extracted CelebA dataset.

# %%
# !ls -al data/img_celeba/

# %%
# !rm -rf img_celeba.7z

# %% [markdown]
# # Download CelebA dataset annotations.

# %% [markdown]
# ### Download dataset annotations.

# %%
# !gdown --id 1xd-d1WRnbt3yJnwh5ORGZI3g-YS-fKM9

# %% [markdown]
# ### Extract dataset annotations at appropiate location.

# %%
# !mv annotations.zip data/img_celeba/.
# !unzip ./data/img_celeba/annotations.zip -d ./data/img_celeba/

# %% [markdown]
# # Align CelebA dataset images.

# %%
# !python ./scripts/align.py --crop_size_h 429 --crop_size_w 429

# %% [markdown]
# ### See aligned CelebA dataset.

# %%
# !ls -al 'data/img_celeba/aligned/align_size(429,429)_move(0.250,0.000)_face_factor(0.450)_jpg/'

# %% [markdown]
# # Compress the dataset.

# %% [markdown]
# ### Restructure dataset files.

# %%
# !mv 'data/img_celeba/aligned/align_size(429,429)_move(0.250,0.000)_face_factor(0.450)_jpg/' img_align_celeba

# %%
# !mv img_align_celeba/data img_align_celeba/images

# %%
# !cp data/img_celeba/train_label.txt img_align_celeba/.

# %%
# !cp data/img_celeba/val_label.txt img_align_celeba/.

# %%
# !cp data/img_celeba/test_label.txt img_align_celeba/.

# %% [markdown]
# ### Compress the dataset.

# %%
# !tar -czf img_align_celeba.tar.gz img_align_celeba

# %%
# !du -sh img_align_celeba.tar.gz

# %% [markdown]
# ### Copy the compressed dataset to the gdrive.

# %%
# !cp img_align_celeba.tar.gz '/content/drive/My Drive/CelebA/.'

# %%
# !ls -al '/content/drive/My Drive/CelebA/'

# %% [markdown]
# ### Remove temporary files.

# %%
# !rm -rf data/img_celeba/annotations.zip

# %%
# !rm -rf data/img_celeba/img_celeba

# %%
# !ls -al data/
